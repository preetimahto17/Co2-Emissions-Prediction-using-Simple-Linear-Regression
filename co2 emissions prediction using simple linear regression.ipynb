# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the csv file
df = pd.read_csv("fuel_consumption_ratings.csv", encoding='ISO-8859-1')
df
# Out:
# C:\Users\Preeti\AppData\Local\Temp\ipykernel_15688\357010024.py:2: DtypeWarning: Columns (0,1,2,3,4,6,7,8,9,10,11,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("fuel_consumption_ratings.csv", encoding='ISO-8859-1')
#      Model   Make         Model.1 Vehicle Class Engine Size  Cylinders  \
# 0     Year    NaN             NaN           NaN         (L)        NaN
# 1     2023  Acura         Integra     Full-size         1.5        4.0
# 2     2023  Acura  Integra A-SPEC     Full-size         1.5        4.0
# 3     2023  Acura  Integra A-SPEC     Full-size         1.5        4.0
# 4     2023  Acura      MDX SH-AWD    SUV: Small         3.5        6.0
# ...    ...    ...             ...           ...         ...        ...
# 7318   NaN    NaN             NaN           NaN         NaN        NaN
# 7319   NaN    NaN             NaN           NaN         NaN        NaN
# ...

# %%
#checking the dimensions of dataframe
df.shape
# Out:
# (7323, 224)

# %%
#checking NaN values
df.isna().sum()
# Out:
# Model            6515
# Make             6503
# Model.1          6524
# Vehicle Class    6524
# Engine Size      6523
#                  ...
# Unnamed: 219     7323
# Unnamed: 220     7323
# Unnamed: 221     7323
# Unnamed: 222     7323
# Unnamed: 223     7323
# Length: 224, dtype: int64

# %%
#Python command that returns a list of the column names
print(df.columns.tolist())
# Out:
# ['Model', 'Make', 'Model.1', 'Vehicle Class', 'Engine Size', 'Cylinders', 'Transmission', 'Fuel', 'Fuel Consumption', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'CO2 Emissions', 'CO2', 'Smog', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed:
# ...

# %%
#removing leading or trailing spaces
df.columns = df.columns.str.strip()
df
# Out:
#      Model   Make         Model.1 Vehicle Class Engine Size  Cylinders  \
# 0     Year    NaN             NaN           NaN         (L)        NaN
# 1     2023  Acura         Integra     Full-size         1.5        4.0
# 2     2023  Acura  Integra A-SPEC     Full-size         1.5        4.0
# 3     2023  Acura  Integra A-SPEC     Full-size         1.5        4.0
# 4     2023  Acura      MDX SH-AWD    SUV: Small         3.5        6.0
# ...    ...    ...             ...           ...         ...        ...
# 7318   NaN    NaN             NaN           NaN         NaN        NaN
# 7319   NaN    NaN             NaN           NaN         NaN        NaN
# 7320   NaN    NaN             NaN           NaN         NaN        NaN
# 7321   NaN    NaN             NaN           NaN         NaN        NaN
# 7322   NaN    NaN             NaN           NaN         NaN        NaN
#
#      Transmission  Fuel Fuel Consumption      Unnamed: 9  ... Unnamed: 214  \
# ...

# %%
#removing unnecessary columns
df.drop(['Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17','Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Un
# 3     2023  Acura  Integra A-SPEC     Full-size         1.5        4.0
# 4     2023  Acura      MDX SH-AWD    SUV: Small         3.5        6.0
# ...    ...    ...             ...           ...         ...        ...
# 7318   NaN    NaN             NaN           NaN         NaN        NaN
# 7319   NaN    NaN             NaN           NaN         NaN        NaN
# 7320   NaN    NaN             NaN           NaN         NaN        NaN
# 7321   NaN    NaN             NaN           NaN         NaN        NaN
# 7322   NaN    NaN             NaN           NaN         NaN        NaN
#
#      Transmission  Fuel Fuel Consumption      Unnamed: 9      Unnamed: 10  \
# ...

# %%
#removing unnecessary rows
df = df.dropna()
df
# Out:
#     Model   Make            Model.1  Vehicle Class Engine Size  Cylinders  \
# 1    2023  Acura            Integra      Full-size         1.5        4.0
# 2    2023  Acura     Integra A-SPEC      Full-size         1.5        4.0
# 3    2023  Acura     Integra A-SPEC      Full-size         1.5        4.0
# 4    2023  Acura         MDX SH-AWD     SUV: Small         3.5        6.0
# 5    2023  Acura  MDX SH-AWD Type S  SUV: Standard         3.0        6.0
# ..    ...    ...                ...            ...         ...        ...
# 795  2023  Volvo        XC40 B5 AWD     SUV: Small         2.0        4.0
# 796  2023  Volvo        XC60 B5 AWD     SUV: Small         2.0        4.0
# 797  2023  Volvo        XC60 B6 AWD     SUV: Small         2.0        4.0
# 798  2023  Volvo        XC90 B5 AWD  SUV: Standard         2.0        4.0
# 799  2023  Volvo        XC90 B6 AWD  SUV: Standard         2.0        4.0
#
#     Transmission Fuel Fuel Consumption Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
df.isna().sum()
# Out:
# Model               0
# Make                0
# Model.1             0
# Vehicle Class       0
# Engine Size         0
# Cylinders           0
# Transmission        0
# Fuel                0
# Fuel Consumption    0
# Unnamed: 9          0
# Unnamed: 10         0
# Unnamed: 11         0
# CO2 Emissions       0
# CO2                 0
# Smog                0
# dtype: int64

# %%
#renaming columns
df = df.rename(columns={
    'Model': 'Model Year',
    'Fuel Consumption': 'FuelConsumptionCity',
    'Engine Size': 'EngineSize',
    'Vehicle Class': 'VehicleClass',
    'Fuel': 'FuelType',
    'Unnamed: 9': 'FuelConsumptionHwy',
    'Unnamed: 10': 'FuelConsumptionComb',
    'Unnamed: 11': 'FuelConsumptionin',
    'CO2 Emissions': 'CO2Emissions'
})
df
# Out:
#     Model Year   Make            Model.1   VehicleClass EngineSize  Cylinders  \
# 1         2023  Acura            Integra      Full-size        1.5        4.0
# 2         2023  Acura     Integra A-SPEC      Full-size        1.5        4.0
# 3         2023  Acura     Integra A-SPEC      Full-size        1.5        4.0
# 4         2023  Acura         MDX SH-AWD     SUV: Small        3.5        6.0
# 5         2023  Acura  MDX SH-AWD Type S  SUV: Standard        3.0        6.0
# ..         ...    ...                ...            ...        ...        ...
# 795       2023  Volvo        XC40 B5 AWD     SUV: Small        2.0        4.0
# 796       2023  Volvo        XC60 B5 AWD     SUV: Small        2.0        4.0
# 797       2023  Volvo        XC60 B6 AWD     SUV: Small        2.0        4.0
# 798       2023  Volvo        XC90 B5 AWD  SUV: Standard        2.0        4.0
# 799       2023  Volvo        XC90 B6 AWD  SUV: Standard        2.0        4.0
#
# ...

# %%
# summarize the data
df.describe(include='all')
# Out:
#        Model Year  Make  Model.1 VehicleClass EngineSize   Cylinders  \
# count         799   799      799          799        799  799.000000
# unique          1    38      626           14         31         NaN
# top          2023  Ford  Mustang   SUV: Small        2.0         NaN
# freq          799    93        5          190        187         NaN
# mean          NaN   NaN      NaN          NaN        NaN    5.627034
# std           NaN   NaN      NaN          NaN        NaN    1.971239
# min           NaN   NaN      NaN          NaN        NaN    3.000000
# 25%           NaN   NaN      NaN          NaN        NaN    4.000000
# 50%           NaN   NaN      NaN          NaN        NaN    6.000000
# 75%           NaN   NaN      NaN          NaN        NaN    6.000000
# max           NaN   NaN      NaN          NaN        NaN   16.000000
#
#        Transmission FuelType FuelConsumptionCity FuelConsumptionHwy  \
# count           799      799                 799                799
# ...

# %%
cdf = df[['EngineSize','Cylinders','FuelConsumptionComb','CO2Emissions']]
cdf.head(9)
# Out:
#   EngineSize  Cylinders FuelConsumptionComb CO2Emissions
# 1        1.5        4.0                 7.2          167
# 2        1.5        4.0                 7.4          172
# 3        1.5        4.0                 7.8          181
# 4        3.5        6.0                11.2          263
# 5        3.0        6.0                12.4          291
# 6        2.0        4.0                 9.9          232
# 7        2.0        4.0                10.3          242
# 8        2.0        4.0                 9.8          230
# 9        2.0        4.0                 9.8          231

# %%
viz = cdf[['EngineSize','Cylinders','FuelConsumptionComb','CO2Emissions']]
viz.hist()
plt.show()

# %%
#plotting each of these features against the Emission, to see how linear their relationship is
plt.scatter(cdf.FuelConsumptionComb, cdf.CO2Emissions,  color='blue')
plt.xlabel("FuelConsumptionComb")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(cdf.EngineSize, cdf.CO2Emissions,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(cdf.Cylinders, cdf.CO2Emissions,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
#splitting data into testing and training sets
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.EngineSize, train.CO2Emissions,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
# my_string = "10.5(L)"
# numeric_value = float(my_string.replace("(L)", ""))

# %%
test['CO2Emissions'] = pd.to_numeric(test['CO2Emissions'], errors='coerce')
# Out:
# C:\Users\Preeti\AppData\Local\Temp\ipykernel_15688\2352262700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['CO2Emissions'] = pd.to_numeric(test['CO2Emissions'], errors='coerce')

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['EngineSize']])
train_y = np.asanyarray(train[['CO2Emissions']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[37.83629564]]
# Intercept:  [135.96296153]

# %%
plt.scatter(train.EngineSize, train.CO2Emissions,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 plt.scatter(train.EngineSize, train.CO2Emissions,  color='blue')
# ----> 2 plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
#       3 plt.xlabel("Engine size")
#       4 plt.ylabel("Emission")
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['EngineSize']])
test_y = np.asanyarray(test[['CO2Emissions']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 28.31
# Residual sum of squares (MSE): 1360.80
# R2-score: 0.62

# %%
train_x = train[['FuelConsumptionComb']]

test_x = test[['EngineSize']]

# %%
regr = linear_model.LinearRegression()
regr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
predictions = regr.predict(test_x)
# Out:
# C:\Users\Preeti\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - EngineSize
# Feature names seen at fit time, yet now missing:
# - FuelConsumptionComb
#
#   warnings.warn(message, FutureWarning)

# %%
print("Mean Absolute Error: %.2f" % np.mean(np.absolute(predictions - test_y)))
# Out:
# Mean Absolute Error: 170.06
